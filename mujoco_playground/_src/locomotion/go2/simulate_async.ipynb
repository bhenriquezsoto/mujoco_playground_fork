# %%
import os
os.environ['MUJOCO_GL'] = 'egl' 
from brax.training.agents.ppo import networks as ppo_networks
from brax.io import model
from mujoco_playground.config import locomotion_params
from mujoco_playground import registry
import jax
from mujoco_playground._src.mjx_env import get_sensor_data
import mujoco
import time
import logging
from mujoco import mjx
from typing import List
from mujoco_playground._src.locomotion.go2 import go2_constants as consts
import mediapy as media


print("Setting up JAX for GPU usage...")
os.environ['JAX_PLATFORMS'] = 'gpu'
jax.config.update('jax_platform_name', 'gpu')
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'
jax.config.update('jax_disable_jit', False)
# Remove jax debug logging
logging.getLogger('jax').setLevel(logging.WARNING)
print("Defining functions")

def get_obs_sensors(model: mujoco.MjModel, data: mjx.Data) -> List:
	"""
	Gets the observation sensors for the Go2 robot

	Args:
		model (mujoco.MjModel): The Mujoco model
		data (mujoco.MjData): The Mujoco data
	Returns:
		List: A list of observation sensors
	"""
	linvel = get_sensor_data(model, data, consts.LOCAL_LINVEL_SENSOR)
	gyro = get_sensor_data(model, data, consts.GYRO_SENSOR)
	resized_matrix = jax.numpy.array(data.site_xmat[model.site("imu").id]).reshape((3, 3))
	gravity = resized_matrix @ jax.numpy.array([0, 0, -1])
	joint_angles = data.qpos[7:] - model.keyframe("home").qpos[7:]
	joint_velocities = data.qvel[6:]

	return [linvel, gyro, gravity, joint_angles, joint_velocities]


def import_model(env_name='Go2JoystickFlatTerrain', env_cfg=None):
	"""
	This function imports the PPO trained model for the task 'Go2JoystickFlatTerrain'.
	"""
	
	
	ppo_params = locomotion_params.brax_ppo_config(env_name)
	model_params = model.load_params('ppo_go2joystick_flatterrain_params_v1_ctrl_002_sim_0004_impratio_100')
	ppo = ppo_networks.make_ppo_networks(action_size=env_cfg.action_size, observation_size=env_cfg.observation_size, **ppo_params.network_factory)
	make_inference = ppo_networks.make_inference_fn(ppo)
	inference_fnTEST = make_inference(model_params, deterministic=True)

	return inference_fnTEST
# Out:
# Setting up JAX for GPU usage...
# Defining functions

# %%
print("Initializing environment and model...")
rng = jax.random.PRNGKey(0)
env_name = 'Go2JoystickFlatTerrain'
env_cfg = registry.get_default_config(env_name)
m = mujoco.MjModel.from_xml_path('./xmls/scene_mjx_feetonly_flat_terrain.xml')
d = mujoco.MjData(m)
print("Setting up renderer and importing model...")
renderer = mujoco.Renderer(m)
print("Importing trained model...")
inference = import_model(env_name, env_cfg)
print("Model imported successfully.")
last_action = jax.numpy.zeros(env_cfg.action_size)
print("JIT compiling inference function...")
inference = jax.jit(inference)
print("Starting main simulation loop...")
command = jax.numpy.array([0.0, 0.0, 3.14]) 
counter_control = 0
counter_init = 0
mujoco.mj_resetData(m, d)
# act_rng, rng = jax.random.split(rng)
# obs_sensors = get_obs_sensors(m, d)
# obs = jax.numpy.concatenate(obs_sensors + [last_action, command_1])
# # Inference from command -> angle off set for each of the joints
# ctrl, _ = inference(obs, act_rng)
timer_control = time.time()
motors_targets = m.keyframe("home").qpos[7:]
render_every = 2
n_steps = 500
images = []
print("Starting simulation...")
# Out:
# Initializing environment and model...
# Setting up renderer and importing model...
# Importing trained model...
# Model imported successfully.
# JIT compiling inference function...
# Starting main simulation loop...
# Starting simulation...

# %%
for i in range(n_steps):
	# print(f"Control dt: {env_cfg.ctrl_dt}s, Sim dt: {env_cfg.sim_dt}s")
	step_start = time.time()
	act_rng, rng = jax.random.split(rng)
	# print(f"Time elapsed for random split: {time.time() - step_start:.4f}s")
	obs_sensors = get_obs_sensors(m, d)
	# print(f"Time elapsed for getting sensors: {time.time() - step_start:.4f}s")
	obs = jax.numpy.concatenate(obs_sensors + [last_action, command])
	# print(f"Time elapsed for concatenating obs: {time.time() - step_start:.4f}s")
	# Inference from command -> angle off set for each of the joints
	ctrl, _ = inference(obs, act_rng)
	# print(f"Time elapsed for inference: {time.time() - step_start:.4f}s")
	motors_targets = m.keyframe("home").qpos[7:] + ctrl * env_cfg.action_scale
	# print(f"Time elapsed for getting motor targets: {time.time() - step_start:.4f}s")
	timer_control = time.time()
	last_action = ctrl
	print("Time used in control loop: {:.4f}s".format(time.time() - step_start))
	d.ctrl = motors_targets	
	for _ in range(int(env_cfg.ctrl_dt / env_cfg.sim_dt)):
		mujoco.mj_step(m, d)

	# time_until_next_step = env_cfg.sim_dt - (time.time() - step_start)
	# if time_until_next_step > 0:
	# 	time.sleep(time_until_next_step)
	# else:
	# 	print(f"Step took longer ({env_cfg.sim_dt - time_until_next_step:.4f}s) than sim_dt of {env_cfg.sim_dt}s")
	# 	pass
	print(f"Timestep {i+1}/{n_steps} completed.")
	if i % render_every == 0:
		renderer.update_scene(d, camera='track')
		images.append(renderer.render())
		
media.show_video(images, fps=1.0 / env_cfg.ctrl_dt / render_every)
# Out:
# Time used in control loop: 0.1451s
# Timestep 1/500 completed.
# Time used in control loop: 0.0016s
# Timestep 2/500 completed.
# Time used in control loop: 0.0012s
# Timestep 3/500 completed.
# Time used in control loop: 0.0020s
# Timestep 4/500 completed.
# Time used in control loop: 0.0015s
# Timestep 5/500 completed.
# Time used in control loop: 0.0019s
# Timestep 6/500 completed.
# Time used in control loop: 0.0012s
# Timestep 7/500 completed.
# Time used in control loop: 0.0024s
# Timestep 8/500 completed.
# Time used in control loop: 0.0014s
# Timestep 9/500 completed.
# Time used in control loop: 0.0019s
# Timestep 10/500 completed.
# Time used in control loop: 0.0012s
# Timestep 11/500 completed.
# Time used in control loop: 0.0017s
# Timestep 12/500 completed.
# Time used in control loop: 0.0011s
# Timestep 13/500 completed.
# Time used in control loop: 0.0016s
# Timestep 14/500 completed.
# Time used in control loop: 0.0011s
# Timestep 15/500 completed.
# Time used in control loop: 0.0021s
# Timestep 16/500 completed.
# Time used in control loop: 0.0019s
# Timestep 17/500 completed.
# Time used in control loop: 0.0019s
# Timestep 18/500 completed.
# Time used in control loop: 0.0015s
# Timestep 19/500 completed.
# Time used in control loop: 0.0018s
# Timestep 20/500 completed.
# Time used in control loop: 0.0011s
# Timestep 21/500 completed.
# Time used in control loop: 0.0020s
# Timestep 22/500 completed.
# Time used in control loop: 0.0013s
# Timestep 23/500 completed.
# Time used in control loop: 0.0020s
# Timestep 24/500 completed.
# Time used in control loop: 0.0014s
# Timestep 25/500 completed.
# Time used in control loop: 0.0019s
# Timestep 26/500 completed.
# Time used in control loop: 0.0013s
# Timestep 27/500 completed.
# Time used in control loop: 0.0022s
# Timestep 28/500 completed.
# Time used in control loop: 0.0015s
# Timestep 29/500 completed.
# Time used in control loop: 0.0019s
# Timestep 30/500 completed.
# Time used in control loop: 0.0018s
# Timestep 31/500 completed.
# Time used in control loop: 0.0018s
# Timestep 32/500 completed.
# Time used in control loop: 0.0020s
# Timestep 33/500 completed.
# Time used in control loop: 0.0016s
# Timestep 34/500 completed.
# Time used in control loop: 0.0015s
# Timestep 35/500 completed.
# Time used in control loop: 0.0018s
# Timestep 36/500 completed.
# Time used in control loop: 0.0011s
# Timestep 37/500 completed.
# Time used in control loop: 0.0025s
# Timestep 38/500 completed.
# Time used in control loop: 0.0020s
# Timestep 39/500 completed.
# Time used in control loop: 0.0018s
# Timestep 40/500 completed.
# Time used in control loop: 0.0015s
# Timestep 41/500 completed.
# Time used in control loop: 0.0021s
# Timestep 42/500 completed.
# Time used in control loop: 0.0012s
# Timestep 43/500 completed.
# Time used in control loop: 0.0018s
# Timestep 44/500 completed.
# Time used in control loop: 0.0014s
# Timestep 45/500 completed.
# Time used in control loop: 0.0017s
# Timestep 46/500 completed.
# Time used in control loop: 0.0013s
# Timestep 47/500 completed.
# Time used in control loop: 0.0020s
# Timestep 48/500 completed.
# Time used in control loop: 0.0017s
# Timestep 49/500 completed.
# Time used in control loop: 0.0018s
# Timestep 50/500 completed.
# Time used in control loop: 0.0014s
# Timestep 51/500 completed.
# Time used in control loop: 0.0016s
# Timestep 52/500 completed.
# Time used in control loop: 0.0015s
# Timestep 53/500 completed.
# Time used in control loop: 0.0017s
# Timestep 54/500 completed.
# Time used in control loop: 0.0012s
# Timestep 55/500 completed.
# Time used in control loop: 0.0021s
# Timestep 56/500 completed.
# Time used in control loop: 0.0013s
# Timestep 57/500 completed.
# Time used in control loop: 0.0020s
# Timestep 58/500 completed.
# Time used in control loop: 0.0013s
# Timestep 59/500 completed.
# Time used in control loop: 0.0019s
# Timestep 60/500 completed.
# Time used in control loop: 0.0011s
# Timestep 61/500 completed.
# Time used in control loop: 0.0019s
# Timestep 62/500 completed.
# Time used in control loop: 0.0011s
# Timestep 63/500 completed.
# Time used in control loop: 0.0016s
# Timestep 64/500 completed.
# Time used in control loop: 0.0014s
# Timestep 65/500 completed.
# Time used in control loop: 0.0019s
# Timestep 66/500 completed.
# Time used in control loop: 0.0014s
# Timestep 67/500 completed.
# Time used in control loop: 0.0022s
# Timestep 68/500 completed.
# Time used in control loop: 0.0011s
# Timestep 69/500 completed.
# Time used in control loop: 0.0019s
# Timestep 70/500 completed.
# Time used in control loop: 0.0015s
# Timestep 71/500 completed.
# Time used in control loop: 0.0017s
# Timestep 72/500 completed.
# Time used in control loop: 0.0011s
# Timestep 73/500 completed.
# Time used in control loop: 0.0023s
# Timestep 74/500 completed.
# Time used in control loop: 0.0013s
# Timestep 75/500 completed.
# Time used in control loop: 0.0019s
# Timestep 76/500 completed.
# Time used in control loop: 0.0016s
# Timestep 77/500 completed.
# Time used in control loop: 0.0019s
# Timestep 78/500 completed.
# Time used in control loop: 0.0010s
# Timestep 79/500 completed.
# Time used in control loop: 0.0018s
# Timestep 80/500 completed.
# Time used in control loop: 0.0012s
# Timestep 81/500 completed.
# Time used in control loop: 0.0016s
# Timestep 82/500 completed.
# Time used in control loop: 0.0014s
# Timestep 83/500 completed.
# Time used in control loop: 0.0018s
# Timestep 84/500 completed.
# Time used in control loop: 0.0016s
# Timestep 85/500 completed.
# Time used in control loop: 0.0017s
# Timestep 86/500 completed.
# Time used in control loop: 0.0014s
# Timestep 87/500 completed.
# Time used in control loop: 0.0017s
# Timestep 88/500 completed.
# Time used in control loop: 0.0014s
# Timestep 89/500 completed.
# Time used in control loop: 0.0021s
# Timestep 90/500 completed.
# Time used in control loop: 0.0012s
# Timestep 91/500 completed.
# Time used in control loop: 0.0017s
# Timestep 92/500 completed.
# Time used in control loop: 0.0011s
# Timestep 93/500 completed.
# Time used in control loop: 0.0018s
# Timestep 94/500 completed.
# Time used in control loop: 0.0012s
# Timestep 95/500 completed.
# Time used in control loop: 0.0017s
# Timestep 96/500 completed.
# Time used in control loop: 0.0011s
# Timestep 97/500 completed.
# Time used in control loop: 0.0025s
# Timestep 98/500 completed.
# Time used in control loop: 0.0017s
# Timestep 99/500 completed.
# Time used in control loop: 0.0021s
# Timestep 100/500 completed.
# Time used in control loop: 0.0013s
# Timestep 101/500 completed.
# Time used in control loop: 0.0017s
# Timestep 102/500 completed.
# Time used in control loop: 0.0010s
# Timestep 103/500 completed.
# Time used in control loop: 0.0018s
# Timestep 104/500 completed.
# Time used in control loop: 0.0016s
# Timestep 105/500 completed.
# Time used in control loop: 0.0015s
# Timestep 106/500 completed.
# Time used in control loop: 0.0013s
# Timestep 107/500 completed.
# Time used in control loop: 0.0021s
# Timestep 108/500 completed.
# Time used in control loop: 0.0013s
# Timestep 109/500 completed.
# Time used in control loop: 0.0018s
# Timestep 110/500 completed.
# Time used in control loop: 0.0016s
# Timestep 111/500 completed.
# Time used in control loop: 0.0018s
# Timestep 112/500 completed.
# Time used in control loop: 0.0012s
# Timestep 113/500 completed.
# Time used in control loop: 0.0019s
# Timestep 114/500 completed.
# Time used in control loop: 0.0015s
# Timestep 115/500 completed.
# Time used in control loop: 0.0018s
# Timestep 116/500 completed.
# Time used in control loop: 0.0014s
# Timestep 117/500 completed.
# Time used in control loop: 0.0018s
# Timestep 118/500 completed.
# Time used in control loop: 0.0013s
# Timestep 119/500 completed.
# Time used in control loop: 0.0020s
# Timestep 120/500 completed.
# Time used in control loop: 0.0014s
# Timestep 121/500 completed.
# Time used in control loop: 0.0017s
# Timestep 122/500 completed.
# Time used in control loop: 0.0013s
# Timestep 123/500 completed.
# Time used in control loop: 0.0017s
# Timestep 124/500 completed.
# Time used in control loop: 0.0013s
# Timestep 125/500 completed.
# Time used in control loop: 0.0020s
# Timestep 126/500 completed.
# Time used in control loop: 0.0012s
# Timestep 127/500 completed.
# Time used in control loop: 0.0018s
# Timestep 128/500 completed.
# Time used in control loop: 0.0016s
# Timestep 129/500 completed.
# Time used in control loop: 0.0019s
# Timestep 130/500 completed.
# Time used in control loop: 0.0012s
# Timestep 131/500 completed.
# Time used in control loop: 0.0016s
# Timestep 132/500 completed.
# Time used in control loop: 0.0019s
# Timestep 133/500 completed.
# Time used in control loop: 0.0019s
# Timestep 134/500 completed.
# Time used in control loop: 0.0014s
# Timestep 135/500 completed.
# Time used in control loop: 0.0018s
# Timestep 136/500 completed.
# Time used in control loop: 0.0013s
# Timestep 137/500 completed.
# Time used in control loop: 0.0018s
# Timestep 138/500 completed.
# Time used in control loop: 0.0015s
# Timestep 139/500 completed.
# Time used in control loop: 0.0017s
# Timestep 140/500 completed.
# Time used in control loop: 0.0013s
# Timestep 141/500 completed.
# Time used in control loop: 0.0019s
# Timestep 142/500 completed.
# Time used in control loop: 0.0014s
# Timestep 143/500 completed.
# Time used in control loop: 0.0018s
# Timestep 144/500 completed.
# Time used in control loop: 0.0013s
# Timestep 145/500 completed.
# Time used in control loop: 0.0017s
# Timestep 146/500 completed.
# Time used in control loop: 0.0012s
# Timestep 147/500 completed.
# Time used in control loop: 0.0017s
# Timestep 148/500 completed.
# Time used in control loop: 0.0015s
# Timestep 149/500 completed.
# Time used in control loop: 0.0018s
# Timestep 150/500 completed.
# Time used in control loop: 0.0015s
# Timestep 151/500 completed.
# Time used in control loop: 0.0018s
# Timestep 152/500 completed.
# Time used in control loop: 0.0015s
# Timestep 153/500 completed.
# Time used in control loop: 0.0020s
# Timestep 154/500 completed.
# Time used in control loop: 0.0011s
# Timestep 155/500 completed.
# Time used in control loop: 0.0021s
# Timestep 156/500 completed.
# Time used in control loop: 0.0014s
# Timestep 157/500 completed.
# Time used in control loop: 0.0017s
# Timestep 158/500 completed.
# Time used in control loop: 0.0012s
# Timestep 159/500 completed.
# Time used in control loop: 0.0018s
# Timestep 160/500 completed.
# Time used in control loop: 0.0015s
# Timestep 161/500 completed.
# Time used in control loop: 0.0019s
# Timestep 162/500 completed.
# Time used in control loop: 0.0016s
# Timestep 163/500 completed.
# Time used in control loop: 0.0024s
# Timestep 164/500 completed.
# Time used in control loop: 0.0016s
# Timestep 165/500 completed.
# Time used in control loop: 0.0020s
# Timestep 166/500 completed.
# Time used in control loop: 0.0015s
# Timestep 167/500 completed.
# Time used in control loop: 0.0022s
# Timestep 168/500 completed.
# Time used in control loop: 0.0015s
# Timestep 169/500 completed.
# Time used in control loop: 0.0018s
# Timestep 170/500 completed.
# Time used in control loop: 0.0011s
# Timestep 171/500 completed.
# Time used in control loop: 0.0026s
# Timestep 172/500 completed.
# Time used in control loop: 0.0014s
# Timestep 173/500 completed.
# Time used in control loop: 0.0019s
# Timestep 174/500 completed.
# Time used in control loop: 0.0013s
# Timestep 175/500 completed.
# Time used in control loop: 0.0017s
# Timestep 176/500 completed.
# Time used in control loop: 0.0015s
# Timestep 177/500 completed.
# Time used in control loop: 0.0017s
# Timestep 178/500 completed.
# Time used in control loop: 0.0014s
# Timestep 179/500 completed.
# Time used in control loop: 0.0016s
# Timestep 180/500 completed.
# Time used in control loop: 0.0014s
# Timestep 181/500 completed.
# Time used in control loop: 0.0020s
# Timestep 182/500 completed.
# Time used in control loop: 0.0016s
# Timestep 183/500 completed.
# Time used in control loop: 0.0019s
# Timestep 184/500 completed.
# Time used in control loop: 0.0014s
# Timestep 185/500 completed.
# Time used in control loop: 0.0019s
# Timestep 186/500 completed.
# Time used in control loop: 0.0012s
# Timestep 187/500 completed.
# Time used in control loop: 0.0017s
# Timestep 188/500 completed.
# Time used in control loop: 0.0016s
# Timestep 189/500 completed.
# Time used in control loop: 0.0018s
# Timestep 190/500 completed.
# Time used in control loop: 0.0013s
# Timestep 191/500 completed.
# Time used in control loop: 0.0019s
# Timestep 192/500 completed.
# Time used in control loop: 0.0012s
# Timestep 193/500 completed.
# Time used in control loop: 0.0018s
# Timestep 194/500 completed.
# Time used in control loop: 0.0012s
# Timestep 195/500 completed.
# Time used in control loop: 0.0016s
# Timestep 196/500 completed.
# Time used in control loop: 0.0013s
# Timestep 197/500 completed.
# Time used in control loop: 0.0019s
# Timestep 198/500 completed.
# Time used in control loop: 0.0011s
# Timestep 199/500 completed.
# Time used in control loop: 0.0022s
# Timestep 200/500 completed.
# Time used in control loop: 0.0014s
# Timestep 201/500 completed.
# Time used in control loop: 0.0021s
# Timestep 202/500 completed.
# Time used in control loop: 0.0019s
# Timestep 203/500 completed.
# Time used in control loop: 0.0019s
# Timestep 204/500 completed.
# Time used in control loop: 0.0016s
# Timestep 205/500 completed.
# Time used in control loop: 0.0016s
# Timestep 206/500 completed.
# Time used in control loop: 0.0012s
# Timestep 207/500 completed.
# Time used in control loop: 0.0023s
# Timestep 208/500 completed.
# Time used in control loop: 0.0015s
# Timestep 209/500 completed.
# Time used in control loop: 0.0019s
# Timestep 210/500 completed.
# Time used in control loop: 0.0015s
# Timestep 211/500 completed.
# Time used in control loop: 0.0020s
# Timestep 212/500 completed.
# Time used in control loop: 0.0017s
# Timestep 213/500 completed.
# Time used in control loop: 0.0017s
# Timestep 214/500 completed.
# Time used in control loop: 0.0014s
# Timestep 215/500 completed.
# Time used in control loop: 0.0018s
# Timestep 216/500 completed.
# Time used in control loop: 0.0012s
# Timestep 217/500 completed.
# Time used in control loop: 0.0017s
# Timestep 218/500 completed.
# Time used in control loop: 0.0014s
# Timestep 219/500 completed.
# Time used in control loop: 0.0019s
# Timestep 220/500 completed.
# Time used in control loop: 0.0014s
# Timestep 221/500 completed.
# Time used in control loop: 0.0023s
# Timestep 222/500 completed.
# Time used in control loop: 0.0013s
# Timestep 223/500 completed.
# Time used in control loop: 0.0019s
# Timestep 224/500 completed.
# Time used in control loop: 0.0013s
# Timestep 225/500 completed.
# Time used in control loop: 0.0019s
# Timestep 226/500 completed.
# Time used in control loop: 0.0013s
# Timestep 227/500 completed.
# Time used in control loop: 0.0019s
# Timestep 228/500 completed.
# Time used in control loop: 0.0012s
# Timestep 229/500 completed.
# Time used in control loop: 0.0018s
# Timestep 230/500 completed.
# Time used in control loop: 0.0013s
# Timestep 231/500 completed.
# Time used in control loop: 0.0022s
# Timestep 232/500 completed.
# Time used in control loop: 0.0016s
# Timestep 233/500 completed.
# Time used in control loop: 0.0025s
# Timestep 234/500 completed.
# Time used in control loop: 0.0022s
# Timestep 235/500 completed.
# Time used in control loop: 0.0023s
# Timestep 236/500 completed.
# Time used in control loop: 0.0012s
# Timestep 237/500 completed.
# Time used in control loop: 0.0018s
# Timestep 238/500 completed.
# Time used in control loop: 0.0013s
# Timestep 239/500 completed.
# Time used in control loop: 0.0016s
# Timestep 240/500 completed.
# Time used in control loop: 0.0015s
# Timestep 241/500 completed.
# Time used in control loop: 0.0024s
# Timestep 242/500 completed.
# Time used in control loop: 0.0012s
# Timestep 243/500 completed.
# Time used in control loop: 0.0018s
# Timestep 244/500 completed.
# Time used in control loop: 0.0012s
# Timestep 245/500 completed.
# Time used in control loop: 0.0021s
# Timestep 246/500 completed.
# Time used in control loop: 0.0013s
# Timestep 247/500 completed.
# Time used in control loop: 0.0023s
# Timestep 248/500 completed.
# Time used in control loop: 0.0019s
# Timestep 249/500 completed.
# Time used in control loop: 0.0017s
# Timestep 250/500 completed.
# Time used in control loop: 0.0012s
# Timestep 251/500 completed.
# Time used in control loop: 0.0016s
# Timestep 252/500 completed.
# Time used in control loop: 0.0011s
# Timestep 253/500 completed.
# Time used in control loop: 0.0016s
# Timestep 254/500 completed.
# Time used in control loop: 0.0013s
# Timestep 255/500 completed.
# Time used in control loop: 0.0016s
# Timestep 256/500 completed.
# Time used in control loop: 0.0011s
# Timestep 257/500 completed.
# Time used in control loop: 0.0016s
# Timestep 258/500 completed.
# Time used in control loop: 0.0012s
# Timestep 259/500 completed.
# Time used in control loop: 0.0021s
# Timestep 260/500 completed.
# Time used in control loop: 0.0012s
# Timestep 261/500 completed.
# Time used in control loop: 0.0019s
# Timestep 262/500 completed.
# Time used in control loop: 0.0011s
# Timestep 263/500 completed.
# Time used in control loop: 0.0021s
# Timestep 264/500 completed.
# Time used in control loop: 0.0011s
# Timestep 265/500 completed.
# Time used in control loop: 0.0027s
# Timestep 266/500 completed.
# Time used in control loop: 0.0013s
# Timestep 267/500 completed.
# Time used in control loop: 0.0020s
# Timestep 268/500 completed.
# Time used in control loop: 0.0019s
# Timestep 269/500 completed.
# Time used in control loop: 0.0017s
# Timestep 270/500 completed.
# Time used in control loop: 0.0015s
# Timestep 271/500 completed.
# Time used in control loop: 0.0016s
# Timestep 272/500 completed.
# Time used in control loop: 0.0010s
# Timestep 273/500 completed.
# Time used in control loop: 0.0015s
# Timestep 274/500 completed.
# Time used in control loop: 0.0014s
# Timestep 275/500 completed.
# Time used in control loop: 0.0017s
# Timestep 276/500 completed.
# Time used in control loop: 0.0010s
# Timestep 277/500 completed.
# Time used in control loop: 0.0016s
# Timestep 278/500 completed.
# Time used in control loop: 0.0013s
# Timestep 279/500 completed.
# Time used in control loop: 0.0016s
# Timestep 280/500 completed.
# Time used in control loop: 0.0011s
# Timestep 281/500 completed.
# Time used in control loop: 0.0017s
# Timestep 282/500 completed.
# Time used in control loop: 0.0013s
# Timestep 283/500 completed.
# Time used in control loop: 0.0017s
# Timestep 284/500 completed.
# Time used in control loop: 0.0012s
# Timestep 285/500 completed.
# Time used in control loop: 0.0018s
# Timestep 286/500 completed.
# Time used in control loop: 0.0013s
# Timestep 287/500 completed.
# Time used in control loop: 0.0017s
# Timestep 288/500 completed.
# Time used in control loop: 0.0012s
# Timestep 289/500 completed.
# Time used in control loop: 0.0016s
# Timestep 290/500 completed.
# Time used in control loop: 0.0010s
# Timestep 291/500 completed.
# Time used in control loop: 0.0017s
# Timestep 292/500 completed.
# Time used in control loop: 0.0012s
# Timestep 293/500 completed.
# Time used in control loop: 0.0020s
# Timestep 294/500 completed.
# Time used in control loop: 0.0015s
# Timestep 295/500 completed.
# Time used in control loop: 0.0019s
# Timestep 296/500 completed.
# Time used in control loop: 0.0011s
# Timestep 297/500 completed.
# Time used in control loop: 0.0017s
# Timestep 298/500 completed.
# Time used in control loop: 0.0012s
# Timestep 299/500 completed.
# Time used in control loop: 0.0020s
# Timestep 300/500 completed.
# Time used in control loop: 0.0014s
# Timestep 301/500 completed.
# Time used in control loop: 0.0020s
# Timestep 302/500 completed.
# Time used in control loop: 0.0019s
# Timestep 303/500 completed.
# Time used in control loop: 0.0020s
# Timestep 304/500 completed.
# Time used in control loop: 0.0014s
# Timestep 305/500 completed.
# Time used in control loop: 0.0016s
# Timestep 306/500 completed.
# Time used in control loop: 0.0011s
# Timestep 307/500 completed.
# Time used in control loop: 0.0016s
# Timestep 308/500 completed.
# Time used in control loop: 0.0011s
# Timestep 309/500 completed.
# Time used in control loop: 0.0019s
# Timestep 310/500 completed.
# Time used in control loop: 0.0015s
# Timestep 311/500 completed.
# Time used in control loop: 0.0016s
# Timestep 312/500 completed.
# Time used in control loop: 0.0011s
# Timestep 313/500 completed.
# Time used in control loop: 0.0020s
# Timestep 314/500 completed.
# Time used in control loop: 0.0014s
# Timestep 315/500 completed.
# Time used in control loop: 0.0019s
# Timestep 316/500 completed.
# Time used in control loop: 0.0015s
# Timestep 317/500 completed.
# Time used in control loop: 0.0016s
# Timestep 318/500 completed.
# Time used in control loop: 0.0013s
# Timestep 319/500 completed.
# Time used in control loop: 0.0025s
# Timestep 320/500 completed.
# Time used in control loop: 0.0020s
# Timestep 321/500 completed.
# Time used in control loop: 0.0015s
# Timestep 322/500 completed.
# Time used in control loop: 0.0012s
# Timestep 323/500 completed.
# Time used in control loop: 0.0021s
# Timestep 324/500 completed.
# Time used in control loop: 0.0017s
# Timestep 325/500 completed.
# Time used in control loop: 0.0023s
# Timestep 326/500 completed.
# Time used in control loop: 0.0016s
# Timestep 327/500 completed.
# Time used in control loop: 0.0018s
# Timestep 328/500 completed.
# Time used in control loop: 0.0012s
# Timestep 329/500 completed.
# Time used in control loop: 0.0018s
# Timestep 330/500 completed.
# Time used in control loop: 0.0016s
# Timestep 331/500 completed.
# Time used in control loop: 0.0017s
# Timestep 332/500 completed.
# Time used in control loop: 0.0013s
# Timestep 333/500 completed.
# Time used in control loop: 0.0016s
# Timestep 334/500 completed.
# Time used in control loop: 0.0012s
# Timestep 335/500 completed.
# Time used in control loop: 0.0020s
# Timestep 336/500 completed.
# Time used in control loop: 0.0014s
# Timestep 337/500 completed.
# Time used in control loop: 0.0019s
# Timestep 338/500 completed.
# Time used in control loop: 0.0013s
# Timestep 339/500 completed.
# Time used in control loop: 0.0017s
# Timestep 340/500 completed.
# Time used in control loop: 0.0010s
# Timestep 341/500 completed.
# Time used in control loop: 0.0017s
# Timestep 342/500 completed.
# Time used in control loop: 0.0014s
# Timestep 343/500 completed.
# Time used in control loop: 0.0022s
# Timestep 344/500 completed.
# Time used in control loop: 0.0014s
# Timestep 345/500 completed.
# Time used in control loop: 0.0021s
# Timestep 346/500 completed.
# Time used in control loop: 0.0015s
# Timestep 347/500 completed.
# Time used in control loop: 0.0018s
# Timestep 348/500 completed.
# Time used in control loop: 0.0017s
# Timestep 349/500 completed.
# Time used in control loop: 0.0018s
# Timestep 350/500 completed.
# Time used in control loop: 0.0014s
# Timestep 351/500 completed.
# Time used in control loop: 0.0020s
# Timestep 352/500 completed.
# Time used in control loop: 0.0012s
# Timestep 353/500 completed.
# Time used in control loop: 0.0020s
# Timestep 354/500 completed.
# Time used in control loop: 0.0015s
# Timestep 355/500 completed.
# Time used in control loop: 0.0018s
# Timestep 356/500 completed.
# Time used in control loop: 0.0013s
# Timestep 357/500 completed.
# Time used in control loop: 0.0022s
# Timestep 358/500 completed.
# Time used in control loop: 0.0013s
# Timestep 359/500 completed.
# Time used in control loop: 0.0018s
# Timestep 360/500 completed.
# Time used in control loop: 0.0017s
# Timestep 361/500 completed.
# Time used in control loop: 0.0021s
# Timestep 362/500 completed.
# Time used in control loop: 0.0016s
# Timestep 363/500 completed.
# Time used in control loop: 0.0018s
# Timestep 364/500 completed.
# Time used in control loop: 0.0018s
# Timestep 365/500 completed.
# Time used in control loop: 0.0017s
# Timestep 366/500 completed.
# Time used in control loop: 0.0013s
# Timestep 367/500 completed.
# Time used in control loop: 0.0021s
# Timestep 368/500 completed.
# Time used in control loop: 0.0016s
# Timestep 369/500 completed.
# Time used in control loop: 0.0019s
# Timestep 370/500 completed.
# Time used in control loop: 0.0012s
# Timestep 371/500 completed.
# Time used in control loop: 0.0019s
# Timestep 372/500 completed.
# Time used in control loop: 0.0014s
# Timestep 373/500 completed.
# Time used in control loop: 0.0019s
# Timestep 374/500 completed.
# Time used in control loop: 0.0015s
# Timestep 375/500 completed.
# Time used in control loop: 0.0016s
# Timestep 376/500 completed.
# Time used in control loop: 0.0013s
# Timestep 377/500 completed.
# Time used in control loop: 0.0017s
# Timestep 378/500 completed.
# Time used in control loop: 0.0013s
# Timestep 379/500 completed.
# Time used in control loop: 0.0020s
# Timestep 380/500 completed.
# Time used in control loop: 0.0016s
# Timestep 381/500 completed.
# Time used in control loop: 0.0019s
# Timestep 382/500 completed.
# Time used in control loop: 0.0012s
# Timestep 383/500 completed.
# Time used in control loop: 0.0017s
# Timestep 384/500 completed.
# Time used in control loop: 0.0012s
# Timestep 385/500 completed.
# Time used in control loop: 0.0020s
# Timestep 386/500 completed.
# Time used in control loop: 0.0015s
# Timestep 387/500 completed.
# Time used in control loop: 0.0017s
# Timestep 388/500 completed.
# Time used in control loop: 0.0011s
# Timestep 389/500 completed.
# Time used in control loop: 0.0018s
# Timestep 390/500 completed.
# Time used in control loop: 0.0014s
# Timestep 391/500 completed.
# Time used in control loop: 0.0018s
# Timestep 392/500 completed.
# Time used in control loop: 0.0013s
# Timestep 393/500 completed.
# Time used in control loop: 0.0022s
# Timestep 394/500 completed.
# Time used in control loop: 0.0013s
# Timestep 395/500 completed.
# Time used in control loop: 0.0021s
# Timestep 396/500 completed.
# Time used in control loop: 0.0012s
# Timestep 397/500 completed.
# Time used in control loop: 0.0015s
# Timestep 398/500 completed.
# Time used in control loop: 0.0015s
# Timestep 399/500 completed.
# Time used in control loop: 0.0016s
# Timestep 400/500 completed.
# Time used in control loop: 0.0018s
# Timestep 401/500 completed.
# Time used in control loop: 0.0022s
# Timestep 402/500 completed.
# Time used in control loop: 0.0013s
# Timestep 403/500 completed.
# Time used in control loop: 0.0017s
# Timestep 404/500 completed.
# Time used in control loop: 0.0018s
# Timestep 405/500 completed.
# Time used in control loop: 0.0019s
# Timestep 406/500 completed.
# Time used in control loop: 0.0011s
# Timestep 407/500 completed.
# Time used in control loop: 0.0018s
# Timestep 408/500 completed.
# Time used in control loop: 0.0015s
# Timestep 409/500 completed.
# Time used in control loop: 0.0017s
# Timestep 410/500 completed.
# Time used in control loop: 0.0017s
# Timestep 411/500 completed.
# Time used in control loop: 0.0021s
# Timestep 412/500 completed.
# Time used in control loop: 0.0010s
# Timestep 413/500 completed.
# Time used in control loop: 0.0018s
# Timestep 414/500 completed.
# Time used in control loop: 0.0015s
# Timestep 415/500 completed.
# Time used in control loop: 0.0018s
# Timestep 416/500 completed.
# Time used in control loop: 0.0010s
# Timestep 417/500 completed.
# Time used in control loop: 0.0016s
# Timestep 418/500 completed.
# Time used in control loop: 0.0012s
# Timestep 419/500 completed.
# Time used in control loop: 0.0021s
# Timestep 420/500 completed.
# Time used in control loop: 0.0015s
# Timestep 421/500 completed.
# Time used in control loop: 0.0016s
# Timestep 422/500 completed.
# Time used in control loop: 0.0012s
# Timestep 423/500 completed.
# Time used in control loop: 0.0019s
# Timestep 424/500 completed.
# Time used in control loop: 0.0012s
# Timestep 425/500 completed.
# Time used in control loop: 0.0017s
# Timestep 426/500 completed.
# Time used in control loop: 0.0011s
# Timestep 427/500 completed.
# Time used in control loop: 0.0018s
# Timestep 428/500 completed.
# Time used in control loop: 0.0014s
# Timestep 429/500 completed.
# Time used in control loop: 0.0020s
# Timestep 430/500 completed.
# Time used in control loop: 0.0016s
# Timestep 431/500 completed.
# Time used in control loop: 0.0021s
# Timestep 432/500 completed.
# Time used in control loop: 0.0012s
# Timestep 433/500 completed.
# Time used in control loop: 0.0021s
# Timestep 434/500 completed.
# Time used in control loop: 0.0012s
# Timestep 435/500 completed.
# Time used in control loop: 0.0019s
# Timestep 436/500 completed.
# Time used in control loop: 0.0015s
# Timestep 437/500 completed.
# Time used in control loop: 0.0015s
# Timestep 438/500 completed.
# Time used in control loop: 0.0012s
# Timestep 439/500 completed.
# Time used in control loop: 0.0019s
# Timestep 440/500 completed.
# Time used in control loop: 0.0011s
# Timestep 441/500 completed.
# Time used in control loop: 0.0021s
# Timestep 442/500 completed.
# Time used in control loop: 0.0011s
# Timestep 443/500 completed.
# Time used in control loop: 0.0015s
# Timestep 444/500 completed.
# Time used in control loop: 0.0011s
# Timestep 445/500 completed.
# Time used in control loop: 0.0017s
# Timestep 446/500 completed.
# Time used in control loop: 0.0013s
# Timestep 447/500 completed.
# Time used in control loop: 0.0017s
# Timestep 448/500 completed.
# Time used in control loop: 0.0014s
# Timestep 449/500 completed.
# Time used in control loop: 0.0018s
# Timestep 450/500 completed.
# Time used in control loop: 0.0010s
# Timestep 451/500 completed.
# Time used in control loop: 0.0018s
# Timestep 452/500 completed.
# Time used in control loop: 0.0010s
# Timestep 453/500 completed.
# Time used in control loop: 0.0015s
# Timestep 454/500 completed.
# Time used in control loop: 0.0011s
# Timestep 455/500 completed.
# Time used in control loop: 0.0017s
# Timestep 456/500 completed.
# Time used in control loop: 0.0010s
# Timestep 457/500 completed.
# Time used in control loop: 0.0018s
# Timestep 458/500 completed.
# Time used in control loop: 0.0011s
# Timestep 459/500 completed.
# Time used in control loop: 0.0020s
# Timestep 460/500 completed.
# Time used in control loop: 0.0011s
# Timestep 461/500 completed.
# Time used in control loop: 0.0018s
# Timestep 462/500 completed.
# Time used in control loop: 0.0010s
# Timestep 463/500 completed.
# Time used in control loop: 0.0021s
# Timestep 464/500 completed.
# Time used in control loop: 0.0012s
# Timestep 465/500 completed.
# Time used in control loop: 0.0018s
# Timestep 466/500 completed.
# Time used in control loop: 0.0011s
# Timestep 467/500 completed.
# Time used in control loop: 0.0020s
# Timestep 468/500 completed.
# Time used in control loop: 0.0013s
# Timestep 469/500 completed.
# Time used in control loop: 0.0017s
# Timestep 470/500 completed.
# Time used in control loop: 0.0011s
# Timestep 471/500 completed.
# Time used in control loop: 0.0018s
# Timestep 472/500 completed.
# Time used in control loop: 0.0015s
# Timestep 473/500 completed.
# Time used in control loop: 0.0018s
# Timestep 474/500 completed.
# Time used in control loop: 0.0013s
# Timestep 475/500 completed.
# Time used in control loop: 0.0016s
# Timestep 476/500 completed.
# Time used in control loop: 0.0018s
# Timestep 477/500 completed.
# Time used in control loop: 0.0020s
# Timestep 478/500 completed.
# Time used in control loop: 0.0010s
# Timestep 479/500 completed.
# Time used in control loop: 0.0018s
# Timestep 480/500 completed.
# Time used in control loop: 0.0012s
# Timestep 481/500 completed.
# Time used in control loop: 0.0018s
# Timestep 482/500 completed.
# Time used in control loop: 0.0015s
# Timestep 483/500 completed.
# Time used in control loop: 0.0015s
# Timestep 484/500 completed.
# Time used in control loop: 0.0011s
# Timestep 485/500 completed.
# Time used in control loop: 0.0026s
# Timestep 486/500 completed.
# Time used in control loop: 0.0016s
# Timestep 487/500 completed.
# Time used in control loop: 0.0018s
# Timestep 488/500 completed.
# Time used in control loop: 0.0013s
# Timestep 489/500 completed.
# Time used in control loop: 0.0016s
# Timestep 490/500 completed.
# Time used in control loop: 0.0014s
# Timestep 491/500 completed.
# Time used in control loop: 0.0017s
# Timestep 492/500 completed.
# Time used in control loop: 0.0014s
# Timestep 493/500 completed.
# Time used in control loop: 0.0018s
# Timestep 494/500 completed.
# Time used in control loop: 0.0013s
# Timestep 495/500 completed.
# Time used in control loop: 0.0017s
# Timestep 496/500 completed.
# Time used in control loop: 0.0011s
# Timestep 497/500 completed.
# Time used in control loop: 0.0019s
# Timestep 498/500 completed.
# Time used in control loop: 0.0013s
# Timestep 499/500 completed.
# Time used in control loop: 0.0017s
# Timestep 500/500 completed.
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
